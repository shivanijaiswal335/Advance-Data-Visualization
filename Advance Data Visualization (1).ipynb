# %% [markdown]
# # Advance Data Visualization of Iris Flower DATA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
ir = pd.read_csv(r"\Users\computer\Downloads\Iris (Advance Data visualization.csv")

# %%
ir
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
ir.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
ir.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
ir.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
ir.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
ir.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
ir.drop('Id',axis=1,inplace=True)

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
ir['Species'] = ir['Species'].astype('category')

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %% [markdown]
# # Data Visualization of iris flowers

# %%
ir['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# Making bar graph by using seaborn countplot visualization.
# see the count or frequency of each catagory
sns.countplot(x = 'Species',data = ir,)
plt.show()

# %%
# In this graph we can see that frequency or count of each catagory are same which is 50

# %%
# Use of seaborn jointplot to check the two column contaning continous variable 
# Are they related to each other
# By using sns.jointplot, we can see individual distribution of each variable with scatter point 
# To use jointplot we can see sepal length and width in individual distribution points
fig = sns.jointplot(x ='SepalLengthCm',y ='SepalWidthCm',data = ir)
fig

# %%
# By using 'hue', in sns.jointplot it show points in different color by which we can analyse easly
fig = sns.jointplot(x = 'SepalLengthCm',y = 'SepalWidthCm',data = ir,hue = "Species")

# %%
# By using kind = "hex" we can see visualizatin in hexagonal format
fig = sns.jointplot(x = 'SepalLengthCm',y = 'SepalWidthCm',data = ir,kind = "hex")

# %%
fig = sns.jointplot(x = 'SepalLengthCm',y = 'SepalWidthCm',data = ir,kind = "reg")

# %%
fig = sns.jointplot(x = 'SepalLengthCm',y = 'SepalWidthCm', data = ir, hue ="Species",kind = "kde")

# %%
# by usibg kind = "hist" ,it show joint visualization 
fig = sns.jointplot(x = 'SepalLengthCm',y = 'SepalWidthCm',data = ir, kind = "hist")
fig

# %%
# By using boxplot we can see visualization in statical format like--max ,min, median and interquatile
fig = plt.gcf()
fig.set_size_inches(8,7)
fig = sns.boxplot(x ='Species',y ='PetalLengthCm',data = ir, order =['Iris-virginica','Iris-versicolor','Iris-setosa'])

# %%
# Using "by" parameter

# %%
ir.boxplot(by ="Species",figsize = (16,4))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
# By using stripplot
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.stripplot(x ='Species',y = 'SepalLengthCm',data = ir, jitter = True, edgecolor ='gray',size = 8,palette = 'winter',orient = 'v')
fig
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
# changing the color of boxes
ax = sns.boxplot(x ='Species',y ="SepalLengthCm",data = ir,)
ax = sns.stripplot(x ='Species',y ='SepalLengthCm',data = ir,jitter = True,edgecolor ='gray',palette ='winter',orient = 'v')
# Define the desired face colors for each box
box_colors = ['red','green','blue']
# Iterate over the artists (boxes)in the plot and assign the colors
for i, artist in enumerate (ax.artists):
    artist.set_facecolor(box_colors[i])
    plt.show()

# %%
# colors changing process
ax = sns.stripplot(x ="Species",y = "PetalWidthCm",data = ir, jitter = True,edgecolor = "gray")
color = ['red','green','blue']
# Create the box plot
ax = sns.boxplot(x ="Species",y = "PetalWidthCm",data = ir,width = 0.5,palette = color)
plt.show()

# %%
# To visualize the distribution of data we will use violin plot and it is probability distribution,
# This chart shows the combination of a Box Plot and Density Plot . which is rotated on each side
# It show the distribution shape of data.
fig = plt.gcf()
fig.set_size_inches(12,8)
fig = sns.violinplot(x = 'Species',y = 'SepalLengthCm',data = ir)
fig
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize =(15,10))
plt.subplot(2,2,1)
sns.violinplot(x = 'Species',y='PetalLengthCm',data = ir)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y ='PetalLengthCm',data = ir)
plt.subplot(2,2,3)
sns.violinplot(x = 'Species',y = 'PetalLengthCm',data = ir)
plt.subplot(2,2,4)
sns.violinplot(x = 'Species',y = 'PetalLengthCm',data = ir)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
## PAIRPLOT
# The pairplot function in seaborn is used to plot pairwise relationships between variables in a data set.
# It creates a matrix of scatteer plots where each variable is plotted against other variable.
# In pairplot like as hitmap we will use to find corelation among all continous variable in dataframe
# In this we will 'hue' as target variable
sns.pairplot(ir,hue = 'Species');

# %%
# To see corelation among the numerical variable
sns.pairplot(ir,kind = "scatter");

# %% [markdown]
# # Heat Map
#    sns.heatmap()is used to create the heatmap.
#    iris.corr()computes the correlation matrix of the Iris dataset using the        corr()function . This matrix contains pairwise corelation between the          numerical columns of dataset.
#    annot = True displays the correlation values in each cell of the heatmap.
#    cmap = 'cubehelix' sets the color map of the heatmap to 'cubehelix', which      is a colormap that varies smoothly between different colors.
#    linewidths = 1 sets the width of the lines separating each cell in the          heatmap to 1
#    linecolor = 'k' sets the color of the lines separating each cell to black .
#    square = True makes each cell in the heatmap square-shaped.
#    mask = False does not mask any cells in the heatmap.
#    vmin = -1 set the minimum and maximum values for the color scale,ensuring      that the heatmap ranges from -1 to 1 representing the correlation values.
#    cbar_kws ={"orientation ":"vertical"} specifies the keyword arguments for      the colorbar. In the case , it sets the orientation of the colorbar to          vertical.
#    cbar = True displays a colorbar next to the heatmap.

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.heatmap(ir.corr(),annot=True,cmap='cubehelix',linewidths =1 , linecolor ='k',square=True, mask=False,vmin =-1, vmax=1)

# %%
fig = plt.gcf()
fig.set_size_inches(12,8)
fig = sns.heatmap(ir.corr(),annot =True, cmap ="cubehelix",linewidths = 1,linecolor = "k",square =True, mask = False, vmin = -1,vmax = 1)

# %% [markdown]
# # Distribution plot
#    the distribution plot is suitable for comparing range and distribution of      groups for numarical data.

# %%
# Data is plotted as x-axis, and y-axis, it show the count or frequency of the range or ivterval
# here we will see the distribution plot of all numerical artibute .
fig = plt.gcf()
fig.set_size_inches(12,6)
ir.hist(edgecolor = 'black',linewidth = 1.2)
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
# Swarm plot, like as stripplot
# A swarm plot, also known as a beeswarm plot, it is a type of categorical scatter plot
# That displays individual data points along an axis based on their categoridal variables.sns.set(style = "darkgrid")
sns.set(style = "darkgrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x = "Species",y="PetalLengthCm", data=ir)

# %%
# To combine swarmplot and violinplot in same data 
# Define the figure size with plt than code for both
sns.set_style("darkgrid",{"axes.facecolor": ".9","grid.color":"0.2"})
fig = plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="Species",y = "PetalLengthCm",data=ir,inner=None)
ax = sns.swarmplot(x="Species",y = "PetalLengthCm", data = ir , color="red",edgecolor = "black")

# %%
sns.set_style("whitegrid")
fig = plt.gcf()
fig.set_size_inches(12,8)
ax = sns.violinplot(x="Species",y = "PetalLengthCm",data=ir,inner= None)
ax = sns.swarmplot(x="Species",y = "PetalLengthCm",data = ir , color = "green")

# %% [markdown]
# # Linear Regression model

# %%
# To find the association between two continous variable
fig = sns.lmplot(x ="PetalLengthCm",y="PetalWidthCm",data = ir)

# %%
fig = sns.lmplot(x = "SepalLengthCm", y = "SepalWidthCm", data = ir )

# %%
fig = sns.lmplot(x="SepalLengthCm",y="PetalLengthCm",data = ir)

# %%
fig = sns.lmplot(x="SepalWidthCm",y="PetalWidthCm", data= ir,hue='Species')

# %%
# Facetgrid,sns.FacetGrid: this is a class in seaborn used to create a grid of subplots based on a variable in the dataset
# It allows you to easily visualize and compare distributions
# or relationships across different subsets of the data .
# first define subplot
a= sns.FacetGrid(ir,hue="Species",height=6)
# To see map the distribution or relationship code with subplot
a.map(sns.kdeplot,"PetalLengthCm")
# you cab add legend
a.add_legend()

# %%
# actorplot function has been deprecated since version 0.9.0. It has been replaced by the more flexible carplot function
# The catplot function can be used to create varsious types of categorical plots based on the kind parameter.
sns.catplot(x='Species',y = 'SepalLengthCm',hue = 'Species', data = ir , kind = 'bar')

# %%
# To show the average value of each category
sns.catplot(x = 'Species', y = 'SepalLengthCm',hue = 'Species', data = ir, kind ='point')

# %%
sns.catplot(x='Species', y = 'SepalLengthCm',hue='Species',data=ir, kind = 'swarm')

# %%
#boxenplot
# It is an extension of the box plot that provides additional information about the shape and variability of data.
fig = plt.gcf()
fig.set_size_inches(9,6)
fig = sns.boxenplot(x='Species',y='SepalLengthCm', data = ir )

# %%
## KDE plot : It allows to see the shape and density of the distribution of sepal length veriable.
# For the 'Iris - setosa' species
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.
sub = ir[ir['Species']=='Iris-setosa']
sns.kdeplot(data=sub, x='SepalLengthCm',y='SepalWidthCm',shade = True,cmap = 'Reds')
plt.title('Iris-setosa')
plt.xlabel('Sepal Length (Cm)')
plt.ylabel('Sepal Width(Cm)') 
plt.show()

# %%
sns.set_style('whitegrid')
f,axes = plt.subplots(2,2,figsize = (10,10))
k1 = sns.boxplot(x = "Species",y="PetalLengthCm",data =ir, ax = axes[0,0])
k2 = sns.violinplot(x='Species',y = "PetalLengthCm",data = ir,ax = axes[0,1])
k3 = sns.stripplot(x = 'Species',y = 'SepalLengthCm',data = ir,jitter = True, edgecolor = 'gray',size = 8, palette = 'winter',orient = 'v',ax=axes[1,0])
# axes[1,1].hist(iris.hist,bin = 10)
k4 = axes[1,1].hist(ir.PetalLengthCm,bins = 100)
#k2.set(x1im=(-1,0.8))
plt.show()

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2,figsize = (14,14))
sns.boxplot(x='Species',y='PetalLengthCm',data = ir,ax = axes[0,0])
sns.violinplot(x='Species',y = 'PetalLengthCm',data=ir,ax=axes[0,1])
sns.stripplot(x='Species',y='SepalLengthCm',data =ir,jitter=True,edgecolor = 'black',size= 6, palette='winter',ax=axes[1,0])
#axes[1,1].hist(ir.PetalLengthCm,bin=10)
axes[1,1].hist(ir.PetalLengthCm,bins = 100)
#k2.set(xlim=(-1,0.8))
plt.show()

# %%
# AREA PLOT: Area plot gives us a visual representation of various dimensions of Iris flower
# there range in dataset. 
ir.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha = 0.4,figsize = (8,4))
# Out:
# <Axes: >
